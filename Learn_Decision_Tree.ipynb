# %%
import numpy as np 
import pandas as pd

# %%
# 1D to 2D 
a = np.random.randint(10, 99, 20)

# %%
a
# Out:
# array([13, 47, 35, 54, 48, 41, 41, 80, 28, 22, 35, 12, 98, 92, 43, 19, 70,
#        76, 37, 29])

# %%
a.shape
# Out:
# (20,)

# %%
b = np.reshape(a, (20, 1))

# %%
b.shape
# Out:
# (20, 1)

# %%
# Confusion Matrix

# %% [markdown]
# ![aww-board (3).png](data:image/png;base64,...)

# %%
# 1. Recall 
# 2. Precision 
# 3. F1 Score

# %%
from sklearn.metrics import classification_report # you will get recall, precision, and f1score for all categories

# %%
# Disadvantage of Linear Models 
# 1. 
# 2. 
# 3.

# %%
# Decision Tree 
# 1. Decision Tree Regression 
# 2. Decision Tree Classifier

# %% [markdown]
# <img src="https://i.stack.imgur.com/BUCmt.png"/>

# %%
# How to choose Root node ?? 

# 1. Gini Score 
# 2. Chi Square

# %% [markdown]
# ![aww-board (4).png](data:image/png;base64,...)
